# %%
from transformers import pipeline

size = "0.5B" # Select from 0.5B, 1.5B, 3B, 7B, 14B, 32B
pipe = pipeline("text-generation", model="Qwen/Qwen2.5-Coder-" + size)
messages = [
    {"role": "user", "content": "Who are you?"},
]
pipe(messages)
